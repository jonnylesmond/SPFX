# %%
import seaborn
import pandas
import matplotlib.pyplot as plt

# %%
trainingdata, walesdata = (
    pandas.read_csv('aggdata/aggpops_transposed(Sheet1).csv'),
    pandas.read_csv('WalesData/WalesPops-Transposed.csv')
)

trainingdata
# Out:
#     Year  Groningen  Fryslân  Drenthe  Overijssel  Flevoland  Gelderland  \
# 0   1942     430271   433541   252367      591063        NaN      951527
# 1   1943     432670   436786   261098      598904        NaN      970296
# 2   1944     436936   444017   269284      612744        NaN     1003125
# 3   1945     441157   452043   264875      620175        NaN     1017876
# 4   1946     442462   453109   266524      623616        NaN     1003481
# ..   ...        ...      ...      ...         ...        ...         ...
# 78  2020     585866   649957   493682     1162406   423021.0     2085952
# 79  2021     586937   651435   494771     1166533   428226.0     2096603
# 80  2022     590170   654019   497743     1171910   434771.0     2110472
# 81  2023     596075   659551   502051     1184333   444701.0     2133708
# 82  2024     601347   661904   504129     1189033   450826.0     2149071
#
#     Utrecht  Noord-Holland  Zuid-Holland  ...  Västra Götaland county  \
# ...

# %%
seaborn.lineplot(data=walesdata, x='Date', y='Cardiff')

# %%
seaborn.lineplot(data=walesdata, x='Date', y='Swansea')

# %%
seaborn.lineplot(data=walesdata, x='Date', y='Newport')

# %%
seaborn.lineplot(data=walesdata, x='Date', y='Blaenau Gwent')

# %% [markdown]
# ## Training Data
# - Groningen - Netherlands
# - Norrbotten County Sweden
# - Uppsala County Sweden
# - Tasmania Australia

# %%
seaborn.lineplot(data=trainingdata, x='Year', y='Groningen')
# Out:
# <Axes: xlabel='Year', ylabel='Groningen'>

# %%
seaborn.lineplot(data=trainingdata, x='Year', y='Norrbotten county')
# Out:
# <Axes: xlabel='Year', ylabel='Norrbotten county'>

# %%
seaborn.lineplot(data=trainingdata, x='Year', y='Uppsala county')
# Out:
# <Axes: xlabel='Year', ylabel='Uppsala county'>

# %%
seaborn.lineplot(data=trainingdata, x='Year', y='Tasmania')
# Out:
# <Axes: xlabel='Year', ylabel='Tasmania'>
